# %% [markdown]
# # Merge Sort ##

# %%
def merge(arr, l, m, r):
    print("Inside Merge function")
    print("l=", l,"r=", r,"m=", m)
    n1 = m - l + 1
    n2 = r - m
    
    L = [0] * (n1)
    R = [0] * (n2)
    
    for i in range(0, n1):
        L[i] = arr[l + i]
        
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
        
    i = 0
    j = 0
    k = l
    
    while i < n1 and j < n2 :
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
        
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
        
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
            
    print(L)
    print(R)
        
def mergeSort(arr,l,r):
    print("Intermidiate array in mergesort")
    for i in range(l , r+1):
        print("%d" %arr[i])
    if l<r:
        m = (l+(r-1))//2
        print("l=", l, "r=", r, "m=", m)
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
        
arr = [12,11,13,5,6,7]
n = len(arr)
print("Given array is ")
for i in range (n):
    print(arr[i])
    
mergeSort(arr,0,n-1)
print("\n\n Sorted array is")
for i in range(n):
    print(arr[i])
# Out:
# Given array is
# 12
# 11
# 13
# 5
# 6
# 7
# Intermidiate array in mergesort
# 12
# 11
# 13
# 5
# 6
# 7
# l= 0 r= 5 m= 2
# Intermidiate array in mergesort
# 12
# 11
# 13
# l= 0 r= 2 m= 0
# Intermidiate array in mergesort
# 12
# Intermidiate array in mergesort
# 11
# 13
# l= 1 r= 2 m= 1
# Intermidiate array in mergesort
# 11
# Intermidiate array in mergesort
# 13
# Inside Merge function
# l= 1 r= 2 m= 1
# [11]
# [13]
# Inside Merge function
# l= 0 r= 2 m= 0
# [12]
# [11, 13]
# Intermidiate array in mergesort
# 5
# 6
# 7
# l= 3 r= 5 m= 3
# Intermidiate array in mergesort
# 5
# Intermidiate array in mergesort
# 6
# 7
# l= 4 r= 5 m= 4
# Intermidiate array in mergesort
# 6
# Intermidiate array in mergesort
# 7
# Inside Merge function
# l= 4 r= 5 m= 4
# [6]
# [7]
# Inside Merge function
# l= 3 r= 5 m= 3
# [5]
# [6, 7]
# Inside Merge function
# l= 0 r= 5 m= 2
# [11, 12, 13]
# [5, 6, 7]
#
#
#  Sorted array is
# 5
# 6
# 7
# 11
# 12
# 13

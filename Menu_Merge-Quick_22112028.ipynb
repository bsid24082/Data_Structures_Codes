# %%
arr = []
n = int(input("Enter the no. of elements: "))
for i in range(0, n):
    ele = int(input())
    arr.append(ele)
    
def partition(arr, low, high):
    i = (low - 1)
    pivot =arr[high]
    
    for j in range(low, high):
        
        if arr[j] <= pivot:
            i = i + 1
            arr[i], arr[j] = arr[j], arr[i]
            
    arr[i + 1], arr[high] = arr[high], arr[i + 1]
    return(i + 1)

def QuickSort(arr, low, high):
    if len(arr) == 1:
        return arr
    
    if low < high:
        pi = partition(arr, low, high)
        QuickSort(arr, low, pi - 1)
        QuickSort(arr, pi + 1, high)
        
def merge(arr, l, m, r):
    print("Inside Merge function")
    print("l=", l,"r=", r,"m=", m)
    n1 = m - l + 1
    n2 = r - m
    
    L = [0] * (n1)
    R = [0] * (n2)
    
    for i in range(0, n1):
        L[i] = arr[l + i]
        
    for j in range(0, n2):
        R[j] = arr[m + 1 + j]
        
    i = 0
    j = 0
    k = l
    
    while i < n1 and j < n2 :
        if L[i] <= R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1
        
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
        
    while j < n2:
        arr[k] = R[j]
        j += 1
        k += 1
            
    print(L)
    print(R)
    
def mergeSort(arr,l,r):
    print("Intermidiate array in mergesort")
    for i in range(l , r+1):
        print("%d" %arr[i])
    if l<r:
        m = (l+(r-1))//2
        print("l=", l, "r=", r, "m=", m)
        mergeSort(arr, l, m)
        mergeSort(arr, m+1, r)
        merge(arr, l, m, r)
        
        
def main():
    print("1 -  Quick Sort")
    print("2 - Merge Sort")
    print("0 - Exit")
    
    while True:
        ch = int(input("Enter your choice: "))
        if ch == 1:
            print("We will sort using Quick-Sort: ")
            QuickSort(arr, 0, n-1)
            for i in range(n):
                print("%d"%arr[i])
        if ch == 2:
            print("We will sort using Merge-Sort: ")
            mergeSort(arr, 0, n-1)
            for i in range(n):
                print("%d"%arr[i])

        if ch == 0:
            print("Exit")
            break
main()

# %%
## MergeSort

def Merge(arr, l, m, r):
    print("Merge-Sort")
    print("l=", l, "r=", r, "m=", m)
    
    n1 = m - l + 1
    n2 = r - m
    
    L = [0] * n1
    R = [0] * n2 
    
    for i in range(0, n1):
        L[i] = arr[l + i]
        
    for i in range(0, n2):
        R[j] = arr[m + 1 + j]
        
    i = 0
    j = 0
    k = 1
    
    while i < n1 and j < n2:
        if L[i] < R[j]:
            arr[k] = L[i]
            i = i + 1
        else:
            arr[k] = R[j]
            j = j + 1
        k += 1
        
    while i < n1:
        arr[k] = L[i]
        i += 1
        k += 1
    while j < n2:
        arr[k] = R[i]
        j += 1
        k += 1
    print(L)
    print(R)
    
def MergeSort(arr, l , r):
    for i in range(l, r+1):
        print(arr[i])
    if l < r:
        MergeSort(arr, l, m)
        MergeSort(arr, m +1, r)
        Merge(arr, l, m, r)
        
        
def partition()
        
def main():
    print("1 - Quicksort")
    print("2 - Mergesort")
    print("0 - Exit")
    
    while True:
        ch = int(input("Enter the choice: "))
        if ch == 0:
            print("Exit")
            break
        if ch == 2:
             print("We will sort using Merge-Sort: ")
            MergeSort(arr, 0, n-1)
            for i in range(n):
                print("%d"%arr[i])
                
        if ch == 1:
            print(" WE Will print using Quick-Sort")
            QuickSort(arr, 0, n-1)
            for i in range(n):
                print(arr[i])

# %% [markdown]
# # Linked-List

# %%
class Node:
    def __init__(self,data):
        self.item = data
        self.ref = None
    
class LinkedList:
    def __init__(self):
        self.start_node = None

    def insert_at_end(self,data):
        new_node = Node(data)
        if self.start_node is None:
            self.start_node = new_node
            return
        temp = self.start_node
        while temp.ref is not None:
            temp = temp.ref
        temp.ref = new_node
        
# creating a node before the initial value   
    def insert_at_first(self,value):
        new_node = Node(value)
        new_node.ref = self.start_node
        self.start_node = new_node 
    
#displaying the value 
    def display(self):
        if self.start_node is None:
                print("empty")
                return
        else:
            temp = self.start_node
            while temp is not None:
                    print(temp.item)
                    temp = temp.ref
            
    def insert_at_pos(self,value,pos):
        new_node = Node(value)
        if pos == 1:
            self.insert_at_first(value)
            return
        temp = self.start_node
        for i in range (1,pos-1):
            temp = temp.ref 
            if(temp == None):
                print("wrong index")
                return
        new_node.ref = temp.ref
        temp.ref = new_node

    # deleting node
    def delete_at_first(self):
        if self.start_node is None:
            print("List is empty")
        
        else:
            value = self.start_node.item
            self.start_node = self.start_node.ref
            print("Element is deleted", value)

# using the second last node 
    def delete_at_last(self):
        if self.start_node is None:
            print("List is Empty")
        
        else:
            temp = self.start_node
            while temp.ref.ref is not None:
                temp = temp.ref
            value = temp.ref.item
            temp.ref = None
            print("value is deleted",value)
        
# deleting from the middle 
    def delete_at_pos(self):
        if self.start_node is None:
            print("List is Empty")
        if pos == 1:
            self.delete_at_first()
        else:
            temp = self.start_node
            for i in range (1,pos-1):
                temp = temp.ref
                if(temp == None):
                    print("wrong index")
                    return
            value = temp.ref.item
            temp.ref = temp.ref.ref
            print("value is deleted",value)

                    

    
def main():
    while True:
        print("1. To Enter a value in 1the beginning of the list")
        print("2. To Enter a value at any position")
        print("3. To Enter a value at the end of the list")
        print("4. To delete the first value")
        print("5. To delete the last value")
        print("6. To delete a value at any position")
        print("7. To display the list")
        print("0. To exit")
    
        ch = int(input("Enter your choice: "))
        ob = LinkedList()
        if ch == 0:
            print("Exit")
            return
        elif ch == 1:
            value = int(input("Enter Value: "))
            ob.insert_at_first(value)
        elif ch==2:
            value=int(input("Enter Value: "))
            pos=int(input("Enter the position of the value: "))
            ob.insert_at_pos(value,pos)
        elif ch==3:
            value=int(input("Enter Value: "))
            ob.insert_at_end(value)
        elif ch==4:
            ob.delete_at_first()
        elif ch==5:
            ob.delete_at_last()
        elif ch==6:
            pos=int(input("Enter the position of the value:"))
            ob.delete_at_pos()
        elif ch==7:
            ob.display()   
    
main()
# Out:
# 1. To Enter a value in 1the beginning of the list
# 2. To Enter a value at any position
# 3. To Enter a value at the end of the list
# 4. To delete the first value
# 5. To delete the last value
# 6. To delete a value at any position
# 7. To display the list
# 0. To exit
# Enter your choice: 3
# Enter Value: 10
# 1. To Enter a value in 1the beginning of the list
# 2. To Enter a value at any position
# 3. To Enter a value at the end of the list
# 4. To delete the first value
# 5. To delete the last value
# 6. To delete a value at any position
# 7. To display the list
# 0. To exit
# Enter your choice: 7
# empty
# 1. To Enter a value in 1the beginning of the list
# 2. To Enter a value at any position
# 3. To Enter a value at the end of the list
# 4. To delete the first value
# 5. To delete the last value
# 6. To delete a value at any position
# 7. To display the list
# 0. To exit

# %%
class Node:
    def __init__(self, data):
        self.item = data
        self.ref = None
        
class LinkedList:
    def __init__(self):
        self.start_node = None
        
    def insert_at_end(self, data):
        new_node = Node(data)
        if self.start_node is None:
            self.start_node = new_node
            return
        else:
            temp = self.start_node
            while temp is not None:
                temp = temp.ref
                temp.ref = new_node
    def insert_at_first(self, data):
        new_node = Node(data)
        new_node.ref = self.start_node
        self.start_node = new_node
    
    def display(self):
        if self.start_node is None:
            print("List is Empty")
            
        else:
            temp = self.start_node
            while temp is not None:
                print(temp.item)
                temp = temp.ref
                
    def insert_as_pos(self, value, pos):
        new_node = Node(value)
        
        if pos == 1:
            self.insert_at_first(value)
            return
        
        temp = self.start_node
        for i in range(1, pos - 1):
            temp = temp.ref
            if (temp == None):
                print("Wrong Index")
                return
        new_node.ref = temp.ref
        temp.ref = new_node
            
    def delete_at_first(self):
        if self.start_node is None:
            print("List is Empty")
            
        else:
            self.start_node = self.start_node.ref
            
    def delete_at_end(self):
        if self.start_node is None:
            print("List is Empty")
            
        else:
            temp = self.start_node
            while temp.ref.ref is not None:
                temp = temp.ref
                temp.ref = None
                
                
    def delete_at_pos(self, pos):
        if self.start_node is None:
            print("List is Empty")
            if pos == 1:
                self.delete_at_first()
                return
        else:
            temp = self.start_node
            for i in range(0, pos - 1):
                temp = temp.ref
                if(temp == None):
                    print("Invalid Index")
            temp.ref = temp.ref.ref
            
        
               
                
def main():
    while True:
        print("1 - To insert at first position")
        print("2 - To insert at desired position")
        print("3 - To print at the end position")
        print("4 - To Display the elements")
        print("5 - To delete the first element")
        print("6 - To delete at desired position")
        print("7 - To delete in the end")
        print("0 - Exit")
        
        ch = int(input("Enter your choice: "))
        ll = LinkedList()
        if ch == 0:
            print("Exit")
            return
        if ch == 1:
            value = int(input("Enter the value that you want to insert: "))
            ll.insert_at_first(value)
            
        if ch == 2:
            value = int(input("Enter the value that you want to insert: "))
            pos = int(input("Enter the position at which you want to insert: "))
            ll.insert_at_pos(value, pos)
            
        if ch == 3:
            value = int(input("Enter the value that you want to insert: "))
            ll.insert_at_end(value)
            
        if ch == 4:
            ll.display()
            
        if ch == 5:
            ll.delete_at_first()
            
        if ch == 6:
            pos = int(input("Enter the position at which you want to insert: "))
            ll.delete_at_pos(pos)
            
        if ch == 7:
            ll.delete_at_end()
            
main()
# Out:
# 1 - To insert at first position
# 2 - To insert at desired position
# 3 - To print at the end position
# 4 - To Display the elements
# 5 - To delete the first element
# 6 - To delete at desired position
# 7 - To delete in the end
# 0 - Exit
# Enter your choice: 1
# Enter the value that you want to insert: 22
# 1 - To insert at first position
# 2 - To insert at desired position
# 3 - To print at the end position
# 4 - To Display the elements
# 5 - To delete the first element
# 6 - To delete at desired position
# 7 - To delete in the end
# 0 - Exit
# Enter your choice: 1
# Enter the value that you want to insert: 44
# 1 - To insert at first position
# 2 - To insert at desired position
# 3 - To print at the end position
# 4 - To Display the elements
# 5 - To delete the first element
# 6 - To delete at desired position
# 7 - To delete in the end
# 0 - Exit
# Enter your choice: 4
# List is Empty
# 1 - To insert at first position
# 2 - To insert at desired position
# ...
